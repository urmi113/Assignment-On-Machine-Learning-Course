# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("supershops.csv.csv")
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
mmx=MinMaxScaler() #creating object for min max scaler
ms_fit=mmx.fit(df[['Marketing Spend']])

# %%
ms_fit
# Out:
# MinMaxScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df['Marketing Spend']=mmx.transform(df[['Marketing Spend']])#transforming data
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0     2.533312e-11       136897.80  471784.10    Dhaka  192261.83
# 1     3.596732e-11       151377.59  443898.53      Ctg  191792.06
# 2     3.394193e-11       101145.55  407934.54  Rangpur  191050.39
# 3     3.193581e-11       118671.85  383199.62    Dhaka  182901.99
# 4     3.143476e-11        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Fit transformation

# %%
df['Administration']=mmx.fit_transform(df[['Administration']])# fit and transform the data
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0     2.533312e-11        0.651744  471784.10    Dhaka  192261.83
# 1     3.596732e-11        0.761972  443898.53      Ctg  191792.06
# 2     3.394193e-11        0.379579  407934.54  Rangpur  191050.39
# 3     3.193581e-11        0.512998  383199.62    Dhaka  182901.99
# 4     3.143476e-11        0.305328  366168.42  Rangpur  166187.94

# %%
mmx2=MinMaxScaler(feature_range=(2,5))
df['Transport']=mmx2.fit_transform(df[['Transport']])
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0     2.533312e-11        0.651744   5.000000    Dhaka  192261.83
# 1     3.596732e-11        0.761972   4.822680      Ctg  191792.06
# 2     3.394193e-11        0.379579   4.593991  Rangpur  191050.39
# 3     3.193581e-11        0.512998   4.436705    Dhaka  182901.99
# 4     3.143476e-11        0.305328   4.328407  Rangpur  166187.94

# %%
df['Profit']=mmx.fit_transform(df[['Profit']])# fit and transform the data
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0     2.533312e-11        0.651744   5.000000    Dhaka  1.000000
# 1     3.596732e-11        0.761972   4.822680      Ctg  0.997355
# 2     3.394193e-11        0.379579   4.593991  Rangpur  0.993178
# 3     3.193581e-11        0.512998   4.436705    Dhaka  0.947292
# 4     3.143476e-11        0.305328   4.328407  Rangpur  0.853171

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df1 = pd.read_csv("supershops.csv.csv")
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1['Marketing Spend']=scaler.fit_transform(df1[['Marketing Spend']])
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
df1['Administration']=scaler.fit_transform(df1[['Administration']])
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753  471784.10    Dhaka  192261.83
# 1         1.955860        1.082807  443898.53      Ctg  191792.06
# 2         1.754364       -0.728257  407934.54  Rangpur  191050.39
# 3         1.554784       -0.096365  383199.62    Dhaka  182901.99
# 4         1.504937       -1.079919  366168.42  Rangpur  166187.94

# %%
df1['Transport']=scaler.fit_transform(df1[['Transport']])
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753   2.165287    Dhaka  192261.83
# 1         1.955860        1.082807   1.929843      Ctg  191792.06
# 2         1.754364       -0.728257   1.626191  Rangpur  191050.39
# 3         1.554784       -0.096365   1.417348    Dhaka  182901.99
# 4         1.504937       -1.079919   1.273550  Rangpur  166187.94

# %%
df1['Profit']=scaler.fit_transform(df1[['Profit']])
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   2.165287    Dhaka  2.011203
# 1         1.955860        1.082807   1.929843      Ctg  1.999430
# 2         1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3         1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4         1.504937       -1.079919   1.273550  Rangpur  1.357740

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
Rosc=RobustScaler()

# %%
df2 = pd.read_csv("supershops.csv.csv")
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df2['Marketing Spend']=Rosc.fit_transform(df2[['Marketing Spend']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %%
df2['Administration']=Rosc.fit_transform(df2[['Administration']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355  471784.10    Dhaka  192261.83
# 1         1.452113        0.697565  443898.53      Ctg  191792.06
# 2         1.303634       -0.524290  407934.54  Rangpur  191050.39
# 3         1.156567       -0.097977  383199.62    Dhaka  182901.99
# 4         1.119836       -0.761543  366168.42  Rangpur  166187.94

# %%
df2['Transport']=Rosc.fit_transform(df2[['Transport']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355   1.552016    Dhaka  192261.83
# 1         1.452113        0.697565   1.383714      Ctg  191792.06
# 2         1.303634       -0.524290   1.166654  Rangpur  191050.39
# 3         1.156567       -0.097977   1.017368    Dhaka  182901.99
# 4         1.119836       -0.761543   0.914576  Rangpur  166187.94

# %%
df2['Profit']=Rosc.fit_transform(df2[['Profit']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.552016    Dhaka  1.698340
# 1         1.452113        0.697565   1.383714      Ctg  1.688874
# 2         1.303634       -0.524290   1.166654  Rangpur  1.673929
# 3         1.156567       -0.097977   1.017368    Dhaka  1.509736
# 4         1.119836       -0.761543   0.914576  Rangpur  1.172943

# %% [markdown]
# # Max Absolute Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler
mas=MaxAbsScaler()

# %%
df3 = pd.read_csv("supershops.csv.csv")
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df3['Marketing Spend']=mas.fit_transform(df3[['Marketing Spend']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df3['Administration']=mas.fit_transform(df3[['Administration']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527  471784.10    Dhaka  192261.83
# 1         0.983359        0.828805  443898.53      Ctg  191792.06
# 2         0.927985        0.553781  407934.54  Rangpur  191050.39
# 3         0.873136        0.649738  383199.62    Dhaka  182901.99
# 4         0.859438        0.500378  366168.42  Rangpur  166187.94

# %%
df3['Transport']=Rosc.fit_transform(df3[['Transport']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527   1.552016    Dhaka  192261.83
# 1         0.983359        0.828805   1.383714      Ctg  191792.06
# 2         0.927985        0.553781   1.166654  Rangpur  191050.39
# 3         0.873136        0.649738   1.017368    Dhaka  182901.99
# 4         0.859438        0.500378   0.914576  Rangpur  166187.94

# %%
df3['Profit']=Rosc.fit_transform(df3[['Profit']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.749527   1.552016    Dhaka  1.698340
# 1         0.983359        0.828805   1.383714      Ctg  1.688874
# 2         0.927985        0.553781   1.166654  Rangpur  1.673929
# 3         0.873136        0.649738   1.017368    Dhaka  1.509736
# 4         0.859438        0.500378   0.914576  Rangpur  1.172943

# %% [markdown]
# # Normal Techniques

# %%
df4 = pd.read_csv("supershops.csv.csv")
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
max=df4['Marketing Spend'].max()
max
# Out:
# 165349.2

# %%
df4['Marketing Spend']=df4['Marketing Spend']/max
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
max1=df4.Administration.max()
df4.Administration=df4.Administration/max1
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527  471784.10    Dhaka  192261.83
# 1         0.983359        0.828805  443898.53      Ctg  191792.06
# 2         0.927985        0.553781  407934.54  Rangpur  191050.39
# 3         0.873136        0.649738  383199.62    Dhaka  182901.99
# 4         0.859438        0.500378  366168.42  Rangpur  166187.94

# %%
max2=df5.Transport.max()
df4.Transport=df4.Transport/max2
df5.head()
